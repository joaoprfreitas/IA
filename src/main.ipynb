# %%
import pandas as pd
import numpy as np

# Read the data
df = pd.read_csv('./datatran2021.csv', encoding='ISO-8859-1', on_bad_lines='skip', sep=';')

df['horario'] = pd.to_datetime(df['horario'], format='%H:%M:%S')
df['horario'] = df['horario'].dt.hour
df.loc[(df['horario'] >= 5) & (df['horario'] < 12), 'fase_dia'] = 'Manhã'
df.loc[(df['horario'] >= 12) & (df['horario'] < 19), 'fase_dia'] = 'Tarde'
df.loc[(df['horario'] >= 19) | (df['horario'] < 5), 'fase_dia'] = 'Noite'

df.dropna()
df = df.dropna(subset=['br'])

# Remove the columns that are not relevant
df = df.drop(['id', 'latitude', 'longitude', 'regional', 'delegacia', 'uop', 'km', 'horario', 'sentido_via', 'uso_solo',
                  'municipio', 'ignorados', 'ilesos', 'pessoas', 'feridos_leves', 'feridos_graves', 'mortos', 'feridos',
                  'veiculos', 'data_inversa', 'tracado_via'], axis=1)

# change causa_acidente to teste if estacionar
df.loc[df['causa_acidente'] == 'Ingestão de álcool ou de substâncias psicoativas pelo pedestre', 'causa_acidente'] = 'Ingestão de álcool e/ou substâncias psicoativas pelo pedestre'
df.loc[df['causa_acidente'] == 'Ingestão de álcool pelo condutor', 'causa_acidente'] = 'Ingestão de álcool e/ou substâncias psicoativas pelo condutor'
df.loc[df['causa_acidente'] == 'Ingestão de substâncias psicoativas pelo condutor', 'causa_acidente'] = 'Ingestão de álcool e/ou substâncias psicoativas pelo condutor'
df.loc[df['causa_acidente'] == 'Ausência de reação do condutor', 'causa_acidente'] = 'Reação tardia ou ineficiente do condutor'

df.loc[df['causa_acidente'] == 'Afundamento ou ondulação no pavimento', 'causa_acidente'] = 'Má condição da via'
df.loc[df['causa_acidente'] == 'Pista em desnível', 'causa_acidente'] = 'Má condição da via'
df.loc[df['causa_acidente'] == 'Pista esburacada', 'causa_acidente'] = 'Má condição da via'
df.loc[df['causa_acidente'] == 'Demais falhas na via', 'causa_acidente'] = 'Má condição da via'

df.loc[df['causa_acidente'] == 'Acumulo de água sobre o pavimento', 'causa_acidente'] = 'Pista Escorregadia'

df.loc[df['causa_acidente'] == 'Acumulo de óleo sobre o pavimento', 'causa_acidente'] = 'Obstrução e/ou acumulo de substâncias na via'
df.loc[df['causa_acidente'] == 'Obstrução na via', 'causa_acidente'] = 'Obstrução e/ou acumulo de substâncias na via'
df.loc[df['causa_acidente'] == 'Acumulo de areia ou detritos sobre o pavimento', 'causa_acidente'] = 'Obstrução e/ou acumulo de substâncias na via'

df.loc[df['causa_acidente'] == 'Iluminação deficiente', 'causa_acidente'] = 'Deficiência do Sistema de Iluminação/Sinalização'

df.loc[df['causa_acidente'] == 'Sinalização mal posicionada', 'causa_acidente'] = 'Problema de sinalização'
df.loc[df['causa_acidente'] == 'Sinalização encoberta', 'causa_acidente'] = 'Problema de sinalização'
df.loc[df['causa_acidente'] == 'Ausência de sinalização', 'causa_acidente'] = 'Problema de sinalização'

df.head(30)

# print number os rows
# print('Number of rows: ', df.shape[0])

# remove row if tipo_acidente is Eventos atípicos
# data = data[~data['tipo_acidente'].str.contains('Eventos atípicos')]
# data.loc[data['tracado_via'] == 'Não Informado']
# Out:
#      dia_semana  uf     br                                     causa_acidente  \
# 0   sexta-feira  SP  116.0           Reação tardia ou ineficiente do condutor
# 1   sexta-feira  AM  174.0           Reação tardia ou ineficiente do condutor
# 2   sexta-feira  CE  222.0                            Velocidade Incompatível
# 3   sexta-feira  RJ  493.0  Ingestão de álcool e/ou substâncias psicoativa...
# 4   sexta-feira  RJ  393.0                                  Condutor Dormindo
# 5   sexta-feira  BA  101.0                            Velocidade Incompatível
# 6   sexta-feira  PR  277.0                                 Pista Escorregadia
# 7   sexta-feira  GO   20.0               Demais falhas mecânicas ou elétricas
# 8   sexta-feira  SC  470.0                             Transitar na contramão
# 9   sexta-feira  MG  381.0                                  Condutor Dormindo
# 10  sexta-feira  SC  470.0  Acessar a via sem observar a presença dos outr...
# 11  sexta-feira  PR  116.0                      Entrada inopinada do pedestre
# 12  sexta-feira  BA  116.0               Demais falhas mecânicas ou elétricas
# 13       sábado  PE  424.0                             Transitar na contramão
# 14       sábado  MG  381.0                                  Condutor Dormindo
# 15       sábado  GO   20.0  Condutor deixou de manter distância do veículo...
# 16       sábado  PI  135.0                                  Condutor Dormindo
# 17       sábado  MS  163.0                             Ultrapassagem Indevida
# 18       sábado  SC  101.0  Trafegar com motocicleta (ou similar) entre as...
# 19       sábado  RS  386.0                             Mal súbito do condutor
# 20       sábado  MG  381.0                                  Condutor Dormindo
# 21       sábado  MT  163.0                             Ultrapassagem Indevida
# 22       sábado  MG  381.0  Condutor deixou de manter distância do veículo...
# 23       sábado  RJ  493.0  Acessar a via sem observar a presença dos outr...
# 24       sábado  SP  116.0                                  Frear bruscamente
# 25       sábado  BA  116.0                      Entrada inopinada do pedestre
# 26       sábado  MG  262.0  Condutor deixou de manter distância do veículo...
# 27       sábado  ES  101.0                                 Pista Escorregadia
# 28       sábado  MG   50.0  Acessar a via sem observar a presença dos outr...
# 29       sábado  PI  316.0                               Problema com o freio
#
#                     tipo_acidente classificacao_acidente fase_dia  \
# 0                      Tombamento    Com Vítimas Feridas    Manhã
# 1                Colisão traseira    Com Vítimas Feridas    Manhã
# 2                      Tombamento    Com Vítimas Feridas    Manhã
# 3                 Colisão lateral    Com Vítimas Feridas    Tarde
# 4                 Colisão frontal    Com Vítimas Feridas    Tarde
# 5                      Tombamento    Com Vítimas Feridas    Tarde
# 6       Saída de leito carroçável    Com Vítimas Feridas    Tarde
# 7                        Incêndio            Sem Vítimas    Tarde
# 8                 Colisão frontal     Com Vítimas Fatais    Tarde
# 9                Colisão traseira    Com Vítimas Feridas    Tarde
# 10            Colisão transversal    Com Vítimas Feridas    Noite
# 11      Atropelamento de Pedestre     Com Vítimas Fatais    Noite
# 12                       Incêndio            Sem Vítimas    Noite
# 13                Colisão lateral    Com Vítimas Feridas    Manhã
# 14      Saída de leito carroçável    Com Vítimas Feridas    Manhã
# 15               Colisão traseira            Sem Vítimas    Manhã
# 16      Saída de leito carroçável    Com Vítimas Feridas    Noite
# 17  Colisão lateral mesmo sentido    Com Vítimas Feridas    Manhã
# 18               Colisão traseira    Com Vítimas Feridas    Manhã
# 19               Colisão traseira    Com Vítimas Feridas    Manhã
# 20      Saída de leito carroçável     Com Vítimas Fatais    Manhã
# 21                Colisão frontal    Com Vítimas Feridas    Manhã
# 22               Colisão traseira    Com Vítimas Feridas    Manhã
# 23               Colisão traseira            Sem Vítimas    Tarde
# 24                     Tombamento    Com Vítimas Feridas    Manhã
# 25      Atropelamento de Pedestre    Com Vítimas Feridas    Tarde
# 26               Colisão traseira    Com Vítimas Feridas    Tarde
# 27                Colisão lateral            Sem Vítimas    Tarde
# 28      Atropelamento de Pedestre    Com Vítimas Feridas    Tarde
# 29            Colisão transversal    Com Vítimas Feridas    Tarde
#
#    condicao_metereologica tipo_pista
# 0                 Nublado      Dupla
# 1               Céu Claro    Simples
# 2               Céu Claro    Simples
# 3                 Nublado    Simples
# 4                 Nublado    Simples
# 5               Céu Claro    Simples
# 6          Garoa/Chuvisco      Dupla
# 7               Céu Claro    Simples
# 8                 Nublado    Simples
# 9               Céu Claro      Dupla
# 10                Nublado    Simples
# 11                  Chuva      Dupla
# 12              Céu Claro    Simples
# 13              Céu Claro    Simples
# 14               Ignorado      Dupla
# 15         Garoa/Chuvisco    Simples
# 16              Céu Claro    Simples
# 17                    Sol    Simples
# 18                    Sol      Dupla
# 19              Céu Claro    Simples
# 20              Céu Claro      Dupla
# 21              Céu Claro    Simples
# 22              Céu Claro      Dupla
# 23                Nublado      Dupla
# 24                Nublado      Dupla
# 25              Céu Claro    Simples
# 26                Nublado      Dupla
# 27                  Chuva    Simples
# 28              Céu Claro      Dupla
# 29              Céu Claro    Simples
